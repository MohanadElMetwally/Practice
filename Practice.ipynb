# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('nba.csv')

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.insert(0,column='First Name', value=df['Name'].str.split().str.get(0))
df
# Out:
#     First Name           Name            Team  Number Position   Age Height  \
# 0        Avery  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1          Jae    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2         John   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3         R.J.    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4        Jonas  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# ..         ...            ...             ...     ...      ...   ...    ...
# 453    Shelvin   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3
# 454       Raul      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1
# 455      Tibor   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3
# 456       Jeff    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0
# 457        NaN            NaN             NaN     NaN      NaN   NaN    NaN
#
#      Weight            College     Salary
# ...

# %%
df.drop(df.tail(1).index,inplace= True)

# %%
df[df['College'] == 'Duke'].shape
# Out:
# (20, 10)

# %%
df[df['Name'].str.match(r'\bJohn\b')==True]
# Out:
#     First Name          Name                Team  Number Position   Age  \
# 2         John  John Holland      Boston Celtics    30.0       SG  27.0
# 126       John  John Jenkins        Phoenix Suns    23.0       SG  25.0
# 216       John   John Henson     Milwaukee Bucks    31.0       PF  25.0
# 382       John     John Wall  Washington Wizards     2.0       PG  25.0
#
#     Height  Weight            College      Salary
# 2      6-5   205.0  Boston University         NaN
# 126    6-4   215.0         Vanderbilt    981348.0
# 216   6-11   229.0     North Carolina   2943221.0
# 382    6-4   195.0           Kentucky  15851950.0

# %%
df.nunique()
# Out:
# First Name    330
# Name          457
# Team           30
# Number         53
# Position        5
# Age            22
# Height         18
# Weight         87
# College       118
# Salary        309
# dtype: int64

# %%
df.iloc[-1].index
# Out:
# Index(['First Name', 'Name', 'Team', 'Number', 'Position', 'Age', 'Height',
#        'Weight', 'College', 'Salary'],
#       dtype='object')

# %%
df['Name'].replace(['Avery Bradley','Jae Crowder'],['Some Name','Some other name'])
# Out:
# 0            Some Name
# 1      Some other name
# 2         John Holland
# 3          R.J. Hunter
# 4        Jonas Jerebko
#             ...
# 452         Trey Lyles
# 453       Shelvin Mack
# 454          Raul Neto
# 455       Tibor Pleiss
# 456        Jeff Withey
# Name: Name, Length: 457, dtype: object

# %%
df.groupby('Team')[['Number','Salary']].mean(numeric_only = True).sort_values('Salary',ascending=False)
# Out:
#                            Number        Salary
# Team
# Cleveland Cavaliers     14.466667  7.642049e+06
# Miami Heat              10.466667  6.347359e+06
# Los Angeles Clippers    19.533333  6.323643e+06
# Oklahoma City Thunder   14.000000  6.251020e+06
# Golden State Warriors   20.866667  5.924600e+06
# Chicago Bulls           19.200000  5.785559e+06
# San Antonio Spurs       17.933333  5.629516e+06
# Memphis Grizzlies       15.555556  5.467920e+06
# Charlotte Hornets       17.133333  5.222728e+06
# Washington Wizards      17.600000  5.088576e+06
# Houston Rockets         14.666667  5.018868e+06
# Atlanta Hawks           19.000000  4.860197e+06
# Los Angeles Lakers      16.066667  4.784695e+06
# Sacramento Kings        16.933333  4.778911e+06
# Dallas Mavericks        20.000000  4.746582e+06
# Toronto Raptors         22.466667  4.741174e+06
# Minnesota Timberwolves  19.571429  4.593054e+06
# New York Knicks         13.250000  4.581494e+06
# ...

# %%
df.groupby('Team').agg({'Salary':['mean','max','min']}).sort_values(by=('Salary','mean'),ascending=False)
# Out:
#                               Salary
#                                 mean         max        min
# Team
# Cleveland Cavaliers     7.642049e+06  22970500.0   111196.0
# Miami Heat              6.347359e+06  22192730.0   261894.0
# Los Angeles Clippers    6.323643e+06  21468695.0   111444.0
# Oklahoma City Thunder   6.251020e+06  20158622.0   222888.0
# Golden State Warriors   5.924600e+06  15501000.0   289755.0
# Chicago Bulls           5.785559e+06  20093064.0   525093.0
# San Antonio Spurs       5.629516e+06  19689000.0   200600.0
# Memphis Grizzlies       5.467920e+06  19688000.0   700902.0
# Charlotte Hornets       5.222728e+06  13500000.0   189455.0
# Washington Wizards      5.088576e+06  15851950.0   200600.0
# Houston Rockets         5.018868e+06  22359364.0   200600.0
# Atlanta Hawks           4.860197e+06  18671659.0   525093.0
# Los Angeles Lakers      4.784695e+06  25000000.0   525093.0
# Sacramento Kings        4.778911e+06  15851950.0   525093.0
# ...

# %%
df.groupby(['Team','College']).mean(numeric_only=True)
# Out:
#                                          Number   Age  Weight      Salary
# Team               College
# Atlanta Hawks      Bucknell                31.0  24.0   240.0    947276.0
#                    Creighton               26.0  35.0   212.0   5746479.0
#                    Florida                 15.0  30.0   245.0  12000000.0
#                    Kansas                  12.0  35.0   190.0   2854940.0
#                    Louisiana Tech           4.0  31.0   246.0  18671659.0
# ...                                         ...   ...     ...         ...
# Washington Wizards LSU                     16.0  29.5   200.0    650601.0
#                    Michigan State           6.0  33.0   220.0   4000000.0
#                    Nevada                   7.0  30.0   190.0   2170465.0
#                    North Carolina State    21.0  27.0   242.0    273038.0
#                    Virginia Tech            8.0  24.0   218.0    561716.0
#
# [336 rows x 4 columns]

# %%
pd.date_range('2003-10-01', periods=10, freq='M')
# Out:
# DatetimeIndex(['2003-10-31', '2003-11-30', '2003-12-31', '2004-01-31',
#                '2004-02-29', '2004-03-31', '2004-04-30', '2004-05-31',
#                '2004-06-30', '2004-07-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
import yfinance as yf

# %%
start = pd.to_datetime('2010-10-01')
end = pd.to_datetime('2023-6-30')

data = yf.download('TSLA',start= start, end= end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-10-01    1.379333    1.383333    1.354000    1.373333    1.373333
# 1    2010-10-04    1.362000    1.411333    1.353333    1.399333    1.399333
# 2    2010-10-05    1.410000    1.418667    1.400667    1.408000    1.408000
# 3    2010-10-06    1.404000    1.417333    1.354667    1.364000    1.364000
# 4    2010-10-07    1.371333    1.376000    1.356000    1.362000    1.362000
# ...         ...         ...         ...         ...         ...         ...
# 3202 2023-06-23  259.290009  262.450012  252.800003  256.600006  256.600006
# 3203 2023-06-26  250.070007  258.369995  240.699997  241.050003  241.050003
# 3204 2023-06-27  243.240005  250.389999  240.850006  250.210007  250.210007
# 3205 2023-06-28  249.699997  259.880005  248.889999  256.239990  256.239990
# 3206 2023-06-29  258.029999  260.739990  253.610001  257.500000  257.500000
#
#          Volume
# 0       8965500
# 1       9654000
# ...

# %%
data.to_csv('Tesla Stocks.csv',index= False)
data.Date = pd.to_datetime(data.Date).dt.year

# %%
plt.figure(figsize=(15,10))
sns.barplot(data, x=data.Date,y= data.High)
# Out:
# <Axes: xlabel='Date', ylabel='High'>

# %%
movies = pd.read_csv('IMDB-Movie-Data.csv', nrows=50)
movies
# Out:
#     Rank                                        Title  \
# 0      1                      Guardians of the Galaxy
# 1      2                                   Prometheus
# 2      3                                        Split
# 3      4                                         Sing
# 4      5                                Suicide Squad
# 5      6                               The Great Wall
# 6      7                                   La La Land
# 7      8                                     Mindhorn
# 8      9                           The Lost City of Z
# 9     10                                   Passengers
# 10    11      Fantastic Beasts and Where to Find Them
# 11    12                               Hidden Figures
# 12    13                                    Rogue One
# 13    14                                        Moana
# 14    15                                     Colossal
# 15    16                      The Secret Life of Pets
# ...

# %%
plt.figure(figsize=(20,8))
plt.plot(movies.Rank, movies['Revenue (Millions)'])

# %%
idx = movies['Revenue (Millions)'].idxmax()
movies.iloc[idx] # type: ignore
# Out:
# Rank                                                                 13
# Title                                                         Rogue One
# Genre                                           Action,Adventure,Sci-Fi
# Description           The Rebel Alliance makes a risky move to steal...
# Director                                                 Gareth Edwards
# Actors                Felicity Jones, Diego Luna, Alan Tudyk, Donnie...
# Year                                                               2016
# Runtime (Minutes)                                                   133
# Rating                                                              7.9
# Votes                                                            323118
# Revenue (Millions)                                               532.17
# Metascore                                                          65.0
# Name: 12, dtype: object

# %%
plt.figure(figsize=(15,8))
plt.scatter(movies.Rank, movies.Rating) # type: ignore

# %%
plt.figure(figsize=(15,8))
plt.bar(movies.Rank, movies.Rating)
plt.show()

# %%
plt.figure(figsize=(20,10))
#First subplot Rank vs Rating
plt.subplot(2,2,1)
plt.bar(movies.Rank, movies.Rating)
plt.xlabel('Rank')
plt.ylabel('Rating')
plt.title('Rank vs Rating')
#Second subplot Rank vs Revenue
plt.subplot(2,2,2)
plt.scatter(movies.Rank, movies['Revenue (Millions)'])
plt.xlabel('Rank')
plt.ylabel('Revenue')
plt.title('Rank vs Revenue')
#Third subplot Runtime vs Votes
plt.subplot(2,2,3)
plt.bar(movies['Runtime (Minutes)'], movies.Votes, width= 2)
plt.xlabel('Runtime')
plt.ylabel('Votes')
plt.title('Runtime vs Votes')
#Fourth subplot Votes vs Revenue 
plt.subplot(2,2,4)
plt.bar(movies['Revenue (Millions)'], movies['Votes'], width=10)
plt.xlabel('Revenue')
plt.ylabel('Votes')
plt.title('Votes vs Revenue')

plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

ax[0][0].bar(movies.Rank, movies.Rating)
ax[0][0].set_xlabel('Rank')
ax[0][0].set_ylabel('Rating')
ax[0][0].set_title('Rank vs Rating')

ax[0][1].scatter(movies.Rank, movies['Revenue (Millions)'])
ax[0][1].set_xlabel('Rankax')
ax[0][1].set_ylabel('Revenueax')
ax[0][1].set_title('Rank vs Revenueax')

ax[1][0].bar(movies['Runtime (Minutes)'], movies.Votes, width= 2)
ax[1][0].set_xlabel('Runtime')
ax[1][0].set_ylabel('Votes')
ax[1][0].set_title('Runtime vs Votes')

ax[1][1].bar(movies['Revenue (Millions)'], movies['Votes'], width=10)
ax[1][1].set_xlabel('Revenue')
ax[1][1].set_ylabel('Votes')
ax[1][1].set_title('Votes vs Revenue')

plt.show()

# %%
quarters = pd.read_csv('quarters.csv', nrows= 5)
quarters
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572

# %%
plt.figure(figsize=(7,7))
plt.pie(quarters['Q1'],labels= quarters['Salesman'], autopct='%1.1f%%') #type: ignore

plt.show()
