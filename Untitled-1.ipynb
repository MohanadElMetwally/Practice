# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.sort_values(by='Name', ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
def SortTable(Data , sort_by, asc= True):
    data = Data.sort_values(by=sort_by, ascending= asc)
    return data

# %%
sortedtable = SortTable(df, 'Name')
sortedtable
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dff = pd.concat([df,df], ignore_index=True)
dff
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 911   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 912      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 913   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 914    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 915            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
import pandas as pd

def identify_duplicates(df, columns):
    # Sort the DataFrame by the specified columns
    sorted_df = df.sort_values(by=columns)
    
    # Identify duplicates based on the sorted columns
    duplicates = sorted_df.duplicated(subset=columns, keep=False)
    
    # Create a new column 'Unique' to mark rows as unique or duplicates
    sorted_df['Unique'] = duplicates.map({True: 'No', False: 'Yes'})
    
    return sorted_df

# %%
dfff = identify_duplicates(dff, 'Name')
dfff
# Out:
#                Name               Team  Number Position   Age Height  Weight  \
# 152    Aaron Brooks      Chicago Bulls     0.0       PG  31.0    6-0   161.0
# 610    Aaron Brooks      Chicago Bulls     0.0       PG  31.0    6-0   161.0
# 814    Aaron Gordon      Orlando Magic     0.0       PF  20.0    6-9   220.0
# 356    Aaron Gordon      Orlando Magic     0.0       PF  20.0    6-9   220.0
# 786  Aaron Harrison  Charlotte Hornets     9.0       SG  21.0    6-6   210.0
# ..              ...                ...     ...      ...   ...    ...     ...
# 729   Zach Randolph  Memphis Grizzlies    50.0       PF  34.0    6-9   260.0
# 695   Zaza Pachulia   Dallas Mavericks    27.0        C  32.0   6-11   275.0
# 237   Zaza Pachulia   Dallas Mavericks    27.0        C  32.0   6-11   275.0
# 457             NaN                NaN     NaN      NaN   NaN    NaN     NaN
# 915             NaN                NaN     NaN      NaN   NaN    NaN     NaN
#
#             College     Salary Unique
# ...

# %%
def remove_duplicates(df, columns):
    
    # Remove duplicates based on the specified columns
    deduplicated_df = df.drop_duplicates(subset=columns, keep='first')
    
    return deduplicated_df

# %%
remove_duplicates(dff, 'Name')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
def join_dataframes(df1, df2, on=None, how='inner', by_position=False):
    if by_position:
        # Join based on row position
        joined_df = pd.concat([df1, df2], axis=1)
    else:
        # Join based on common columns
        joined_df = pd.merge(df1, df2, on=on, how=how) #type: ignore
    
    return joined_df

# %%
# Example DataFrames
data1 = {
    'Name': ['John', 'Alice', 'Bob'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
}
df1 = pd.DataFrame(data1)

data2 = {
    'Name': ['John', 'Alice', 'Charlie'],
    'Salary': [5000, 6000, 7000],
    'Country': ['USA', 'UK', 'France']
}
df2 = pd.DataFrame(data2)

# %%
joined_df = join_dataframes(df, df, on='Name', how='inner')
joined_df
# Out:
#               Name          Team_x  Number_x Position_x  Age_x Height_x  \
# 0    Avery Bradley  Boston Celtics       0.0         PG   25.0      6-2
# 1      Jae Crowder  Boston Celtics      99.0         SF   25.0      6-6
# 2     John Holland  Boston Celtics      30.0         SG   27.0      6-5
# 3      R.J. Hunter  Boston Celtics      28.0         SG   22.0      6-5
# 4    Jonas Jerebko  Boston Celtics       8.0         PF   29.0     6-10
# ..             ...             ...       ...        ...    ...      ...
# 453   Shelvin Mack       Utah Jazz       8.0         PG   26.0      6-3
# 454      Raul Neto       Utah Jazz      25.0         PG   24.0      6-1
# 455   Tibor Pleiss       Utah Jazz      21.0          C   26.0      7-3
# 456    Jeff Withey       Utah Jazz      24.0          C   26.0      7-0
# 457            NaN             NaN       NaN        NaN    NaN      NaN
#
#      Weight_x          College_x   Salary_x          Team_y  Number_y  \
# ...

# %%
joined_df_by_position = join_dataframes(df, df, by_position=True)
joined_df_by_position
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary           Name            Team  Number  \
# ...

# %%
def join_dataframes(df1, df2, on= None, how= 'inner', by_position= False):
    if by_position:
        # Join based on row position
        joined_df = pd.concat([df1, df2], axis= 1)
    elif on is not None:
        # Join based on common columns
        joined_df = pd.merge(df1, df2, on= on, how= how)
    else:
        # Join based on column names
        joined_df = pd.merge(df1, df2, left_on= df1.columns.tolist(), right_on= df2.columns.tolist(), how= how)
    
    return joined_df

# %%
joined_df_by_position = join_dataframes(df, df)
joined_df_by_position
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
week1['Customer ID'].value_counts()
# Out:
# 77     4
# 331    3
# 100    3
# 798    2
# 226    2
#       ..
# 117    1
# 937    1
# 63     1
# 144    1
# 535    1
# Name: Customer ID, Length: 221, dtype: int64

# %%
joined_df = join_dataframes(week1, week2, on='Customer ID', how='right')
joined_df
# Out:
#      Customer ID  Food ID_x  Food ID_y
# 0            688        NaN         10
# 1            813        NaN          7
# 2            495        NaN         10
# 3            189        4.0          5
# 4            267        NaN          3
# ..           ...        ...        ...
# 254          783        6.0         10
# 255          556        NaN         10
# 256          547        NaN          9
# 257          252        NaN          9
# 258          249        9.0          6
#
# [259 rows x 3 columns]

# %%
identify_duplicates(joined_df,'Customer ID')
# Out:
#      Customer ID  Food ID_x  Food ID_y Unique
# 17             8        NaN          6    Yes
# 26            13        NaN          2    Yes
# 33            21        4.0          4     No
# 32            21        4.0          4     No
# 132           24        NaN          8    Yes
# ..           ...        ...        ...    ...
# 155          968        1.0          4    Yes
# 58           969        NaN          3    Yes
# 176          977        NaN          7    Yes
# 112          994        NaN          2    Yes
# 164          996        NaN         10    Yes
#
# [259 rows x 4 columns]

# %%
removed = remove_duplicates(joined_df,'Customer ID')

# %%
identify_duplicates(removed, 'Customer ID')['Unique'].value_counts()
# Out:
# Yes    224
# Name: Unique, dtype: int64

# %%
join_dataframes(week1,week2)
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
def join_dataframes(df1, df2, on=None, how='inner', by_position=False, column_position=None):
    if by_position:
        # Join based on row position
        joined_df = pd.concat([df1, df2], axis=1)
    elif on is not None:
        # Join based on common columns
        joined_df = pd.merge(df1, df2, on=on, how=how)
    elif column_position is not None:
        # Join based on column position
        joined_df = pd.concat([df1, df2], ignore_index=True)
    else:
        # Join based on column names
        joined_df = pd.merge(df1, df2, left_on=df1.columns.tolist(), right_on=df2.columns.tolist(), how=how)
    
    return joined_df

# %%
joined = join_dataframes(week1,week2, column_position= True)

# %%
remove_duplicates(joined,'Customer ID')
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 487          855        4
# 489          559       10
# 492          276        4
# 496          556       10
# 498          252        9
#
# [399 rows x 2 columns]

# %%
# Out:
#      Customer ID  Food ID  Customer ID  Food ID
# 0            537        9          688       10
# 1             97        4          813        7
# 2            658        1          495       10
# 3            202        2          189        5
# 4            155        9          267        3
# ..           ...      ...          ...      ...
# 245          413        9          783       10
# 246          926        6          556       10
# 247          134        3          547        9
# 248          396        6          252        9
# 249          535       10          249        6
#
# [250 rows x 4 columns]

# %%
def concat_dataframes(data_frame1, data_frame2, row_position= None, ignore_idx= False):
    # Concatenate dataframes based on position
    if row_position:
        concatenated_dataframe= pd.concat([data_frame1,data_frame2], axis= 1, ignore_index= ignore_idx)
    else:
        concatenated_dataframe = pd.concat([data_frame1,data_frame2], ignore_index= ignore_idx)
    
    return concatenated_dataframe

# %%
concat_dataframes(week1,week2, row_position= False, ignore_idx=False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
def merge_dataframes(df1, df2, on_column= None, join_type= 'inner'):
    if on_column is not None:
        # Join based on common columns
        joined_df = pd.merge(df1, df2, on=on_column, how= join_type)
    else:
        # Join based on column names
        joined_df = pd.merge(df1, df2, left_on=df1.columns.tolist(), right_on=df2.columns.tolist(), how= join_type)
    
    return joined_df

# %%
merge_dataframes(week1, week2, on_column= 'Customer ID', join_type= 'outer')
# Out:
#      Customer ID  Food ID_x  Food ID_y
# 0            537        9.0        5.0
# 1             97        4.0        NaN
# 2            658        1.0        NaN
# 3            202        2.0        NaN
# 4            155        9.0        3.0
# ..           ...        ...        ...
# 449          855        NaN        4.0
# 450          559        NaN       10.0
# 451          276        NaN        4.0
# 452          556        NaN       10.0
# 453          252        NaN        9.0
#
# [454 rows x 3 columns]
